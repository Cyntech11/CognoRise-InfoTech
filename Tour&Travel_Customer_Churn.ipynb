# %% [markdown]
# **Problem Statement**
#
# A tour & travels company wants to predict whether a customer will churn or not. Based on a few customer characteristics like their age, frequent flyer status, annual income class, services opted, account snick to social media, booked hotel or not, Target.
#
# The analysis and forecasting are based on the customer churn's impact on yearly income, hotel reservations, and whether or not they were made in order to assist the business in developing predictive models, saving money, and performing fascinating EDAs.

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# **Loading the Dataset**

# %%
df = pd.read_csv('/content/Customertravel.csv')
# Out:
#    Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 0   34            No     Middle Income              6
# 1   34           Yes        Low Income              5
# 2   37            No     Middle Income              3
# 3   30            No     Middle Income              2
# 4   30            No        Low Income              1
#
#   AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 0                         No              Yes       0
# 1                        Yes               No       1
# 2                        Yes               No       0
# 3                         No               No       0
# 4                         No               No       0

# %% [markdown]
# **Data Cleaning**

# %%
df.head()
# Out:
#    Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 0   34            No     Middle Income              6
# 1   34           Yes        Low Income              5
# 2   37            No     Middle Income              3
# 3   30            No     Middle Income              2
# 4   30            No        Low Income              1
#
#   AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 0                         No              Yes       0
# 1                        Yes               No       1
# 2                        Yes               No       0
# 3                         No               No       0
# 4                         No               No       0

# %%
df.tail()
# Out:
#      Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 949   31           Yes        Low Income              1
# 950   30            No     Middle Income              5
# 951   37            No     Middle Income              4
# 952   30            No        Low Income              1
# 953   31           Yes       High Income              1
#
#     AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 949                         No               No       0
# 950                         No              Yes       0
# 951                         No               No       0
# 952                        Yes              Yes       0
# 953                         No               No       0

# %%
print('The null values in the dataset\n')

df.isna().sum()
# Out:
# The null values in the dataset
# Age                           0
# FrequentFlyer                 0
# AnnualIncomeClass             0
# ServicesOpted                 0
# AccountSyncedToSocialMedia    0
# BookedHotelOrNot              0
# Target                        0
# dtype: int64

# %%
print('Shape of the dataset\n')

df.shape
# Out:
# Shape of the dataset
# (954, 7)

# %%
print('Columns of the dataset\n')

df.columns
# Out:
# Columns of the dataset
# Index(['Age', 'FrequentFlyer', 'AnnualIncomeClass', 'ServicesOpted',
#        'AccountSyncedToSocialMedia', 'BookedHotelOrNot', 'Target'],
#       dtype='object')

# %%
print('Information of the dataset\n')

df.info()
# Out:
# Information of the dataset
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         954 non-null    int64
#  1   FrequentFlyer               954 non-null    object
#  2   AnnualIncomeClass           954 non-null    object
#  3   ServicesOpted               954 non-null    int64
#  4   AccountSyncedToSocialMedia  954 non-null    object
#  5   BookedHotelOrNot            954 non-null    object
#  6   Target                      954 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 52.3+ KB

# %%
print('The duplicate values in the dataset\n')

df.duplicated().sum()
# Out:
# The duplicate values in the dataset
# 507

# %% [markdown]
# **I Observed that there are five hundred and seven duplicated values in the dataset**

# %%
print('The Statistical distribution\n')

df.describe()
# Out:
# The Statistical distribution
#               Age  ServicesOpted      Target
# count  954.000000     954.000000  954.000000
# mean    32.109015       2.437107    0.234801
# std      3.337388       1.606233    0.424097
# min     27.000000       1.000000    0.000000
# 25%     30.000000       1.000000    0.000000
# 50%     31.000000       2.000000    0.000000
# 75%     35.000000       4.000000    0.000000
# max     38.000000       6.000000    1.000000

# %%
df.describe(include = 'object')
# Out:
#        FrequentFlyer AnnualIncomeClass AccountSyncedToSocialMedia  \
# count            954               954                        954
# unique             3                 3                          2
# top               No     Middle Income                         No
# freq             608               409                        594
#
#        BookedHotelOrNot
# count               954
# unique                2
# top                  No
# freq                576

# %%
df.select_dtypes('number').corr()
# Out:
#                     Age  ServicesOpted    Target
# Age            1.000000      -0.012422 -0.131534
# ServicesOpted -0.012422       1.000000  0.038646
# Target        -0.131534       0.038646  1.000000

# %%
df.describe(include = 'object')
# Out:
#        FrequentFlyer AnnualIncomeClass AccountSyncedToSocialMedia  \
# count            954               954                        954
# unique             3                 3                          2
# top               No     Middle Income                         No
# freq             608               409                        594
#
#        BookedHotelOrNot
# count               954
# unique                2
# top                  No
# freq                576

# %%
for col in df.describe(include = 'object') .columns:
    print(col)
    print(df[col].unique())
    print('-'*50)
# Out:
# FrequentFlyer
# ['No' 'Yes' 'No Record']
# --------------------------------------------------
# AnnualIncomeClass
# ['Middle Income' 'Low Income' 'High Income']
# --------------------------------------------------
# AccountSyncedToSocialMedia
# ['No' 'Yes']
# --------------------------------------------------
# BookedHotelOrNot
# ['Yes' 'No']
# --------------------------------------------------

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in df.describe(include = 'object') .columns:
    df[col] = le.fit_transform(df[col])

# %%
df.head(2)
# Out:
#    Age  FrequentFlyer  AnnualIncomeClass  ServicesOpted  \
# 0   34              0                  2              6
# 1   34              2                  1              5
#
#    AccountSyncedToSocialMedia  BookedHotelOrNot  Target
# 0                           0                 1       0
# 1                           1                 0       1

# %%
px.bar(df.groupby('Age')['FrequentFlyer'].mean())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="81d47a7c-0fe1-4b85-85f3-1b67f33d666a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81d47a7c-0fe1-4b85-85f3-1b67f33d666a")) {                    Plotly.newPlot(                        "81d47a7c-0fe1-4b85-85f3-1b67f33d666a",                        [{"alignmentgroup":"True","hovertemplate":"variable=FrequentFlyer\u003cbr\u003eAge=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FrequentFlyer","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"FrequentFlyer","offsetgroup":"FrequentFlyer","orientation":"v","showlegend":true,"textposition":"auto","x":[27,28,29,30,31,33,34,35,36,37,38],"xaxis":"x","y":[0.6612903225806451,0.6197183098591549,0.7,0.5677966101694916,0.6116504854368932,1.0,0.8317757009345794,0.5769230769230769,0.8208955223880597,0.6111111111111112,0.6774193548387096],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"e ...

# %% [markdown]
# **Hotel Booking Visualization**

# %%
churn_per = df['BookedHotelOrNot'].value_counts(normalize=1)
print(churn_per)

px.bar(["Booked","NotBooked"], df['BookedHotelOrNot'].value_counts(normalize=1), title="How Hotel Bookings Affect Customer Churn")
# Out:
# BookedHotelOrNot
# 0    0.603774
# 1    0.396226
# Name: proportion, dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a612072e-60c9-4166-99b5-f22c6bd17a80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a612072e-60c9-4166-99b5-f22c6bd17a80")) {                    Plotly.newPlot(                        "a612072e-60c9-4166-99b5-f22c6bd17a80",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003eindex=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.6037735849056604,0.39622641509433965],"xaxis":"x","y":[0,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scat ...

# %% [markdown]
# **Customers who have made hotel reservations account for 39% of the overall population, whereas those who have not made hotel reservations account for 60% of the population, which is a significant number.**

# %%
income = df.groupby(['AnnualIncomeClass'])

income = income.size()

income
# Out:
# AnnualIncomeClass
# 0    159
# 1    386
# 2    409
# dtype: int64

# %%
px.pie(values = income , names = ("High Income", "Low Income", "Middle Income" ), title = 'How Income impacts Customers Churn')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="
,27,27,30,36,27,34,37,38,37,37,37,37,36,35,30,30,30,30,30,34,30,30,34,37,30,29,33,34,38,31,30,35,30,37,34,30,29,30,27,30,36,37,30,37,30,27,37,28,34,29,37,28,30,35,30,30,37,30,30,28,36,36,29,35,30,34,30,33,37,30,30,28,35,37,30,30,28,36,28,30,31,29,33,29,29,31,29,27,28,31,30,28,30,27,37,36,30,36,29,36,34,34,29,37,30,35,27,36,35,30,31,30,29,36,29,37,30,37,36,28,37,30,30,30,30,31,30,29,37,29,37,36,31,27,33,27,37,30,29,34,30,33,29,37,30,33,30,30,36,37,37,37,31,31,30,29,37,30,37,38,30,30,36,35,31,30,29,36,37,29,28,30,30,29,31,37,30,37,33,30,31,38,34,30,35,27,29,29,27,34,29,30,31,34,31,31,37,37,30,35,38,30,30,28,35,30,30,37,34,34,34,33,31,29,31,33,29,37,33,31,28,36,33,31,27,37,29,30,30,27,37,31,30,35,31,30,35,37,28,37,29,37,34,36,38,30,31,31,28,30,37,31,31,36,30,30,31,38,37,35,30,29,34,35,28,37,30,29,30,37,33,30,31,28,34,34,36,30,36,38,27,29,35,30,31,30,28,28,31,30,31,28,30,38,35,34,30,30,38,36,31,31,34,33,30,36,34,34,27,31,36,37,30,30,30,37,28,37,28,37,29,34,34,35,30,28,30,36,28,35,36,31,30,34,33,37,36,28,28,37,30,29,30,30,29,36,30,30,34,27,37,27,31,36,30,27,38,31,31,30,37,30,31],"xaxis":"x","y":[2,1,2,2,1,0,2,1,1,0,1,2,2,1,2,1,1,0,2,1,2,0,1,2,2,1,2,2,1,0,2,1,2,0,1,2,1,1,2,2,1,0,2,1,2,0,1,2,2,1,1,2,1,0,2,1,2,0,1,2,2,1,2,2,1,0,2,1,2,0,1,1,2,1,2,2,1,0,1,1,2,0,1,2,2,1,2,2,1,0,2,1,1,0,1,2,2,1,2,1,1,0,2,1,2,0,1,2,2,1,2,2,1,0,2,1,2,0,1,2,1,1,2,2,1,0,2,1,2,0,1,2,2,1, ...

# %% [markdown]
# **Age 30 has the highest AnnualIncomeClass**

# %%
df.head(1)
# Out:
#    Age  FrequentFlyer  AnnualIncomeClass  ServicesOpted  \
# 0   34              0                  2              6
#
#    AccountSyncedToSocialMedia  BookedHotelOrNot  Target
# 0                           0                 1       0

# %%
FrequentFlyer = df.groupby('FrequentFlyer')
FrequentFlyer = FrequentFlyer.size()
FrequentFlyer
# Out:
# FrequentFlyer
# 0    608
# 1     60
# 2    286
# dtype: int64

# %%
px.pie(values = FrequentFlyer , names = ("High FrequentFlyer", "Low FrequentFlyer", "Middle FrequentFlyer" ), title = 'How FrequentFlyer impacts Customers Churn')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ac508f4f-82d4-4969-a27e-93cf0b52af15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac508f4f-82d4-4969-a27e-93cf0b52af15")) {                    Plotly.newPlot(                        "ac508f4f-82d4-4969-a27e-93cf0b52af15",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["High FrequentFlyer","Low FrequentFlyer","Middle FrequentFlyer"],"legendgroup":"","name":"","showlegend":true,"values":[608,60,286],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinew ...

# %% [markdown]
# **I found that customers with the highest frequentflyer have the highest proportion of customer churn, whereas those with the lowest (6.29%) and middle (30%), have the lowest percentage of churn**

# %%
acc = df.groupby('AccountSyncedToSocialMedia')
acc = acc.size()
acc
# Out:
# AccountSyncedToSocialMedia
# 0    594
# 1    360
# dtype: int64
